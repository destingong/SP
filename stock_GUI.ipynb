# %%
# !pip install pyngrok -q
# !pip install taipy -q
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.3

# %%
import taipy as tp
import taipy.gui.builder as tgb
from taipy.gui import Icon
from taipy import Config

# %%
from taipy import Gui
import taipy.gui.builder as tgb

with tgb.Page() as root_page:
    tgb.navbar()
    tgb.text("# Multi-page application", mode="md")

with tgb.Page() as home_page:
    tgb.text("# Home", mode="md")

with tgb.Page() as about_page:
    tgb.text("# About", mode="md")

pages = {
    "/": root_page,
    "home": home_page,
    "about": about_page
}
# Out:
# [2025-01-14 08:02:54.634][Taipy][INFO] Running in 'single_client' mode in notebook environment
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# INFO:Taipy:Running in 'single_client' mode in notebook environment
# [2025-01-14 08:02:54.711][Taipy][INFO]  * NGROK Public Url: https://b81b-34-29-26-137.ngrok-free.app
# INFO:Taipy: * NGROK Public Url: https://b81b-34-29-26-137.ngrok-free.app
# [2025-01-14 08:02:54.815][Taipy][INFO] Gui server has been stopped.
# INFO:Taipy:Gui server has been stopped.
# [2025-01-14 08:02:54.821][Taipy][INFO]  * Server starting on http://127.0.0.1:5000
# INFO:Taipy: * Server starting on http://127.0.0.1:5000
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.

# %%
import sys
sys.path.append('drive/MyDrive/SP')
from tokens import NGROK_TOKEN

Gui(pages=pages).run(
    title='Data Science Dashboard',
    ngrok_token=NGROK_TOKEN
)

# %%
# !taipy run drive/MyDrive/SP/main.py -q
# Out:
# [2025-01-14 07:56:29.489][Taipy][INFO]  * NGROK Public Url: https://d942-34-29-26-137.ngrok-free.app
# [2025-01-14 07:56:29.503][Taipy][INFO]  * Server starting on http://127.0.0.1:5000
# kill
# /usr/lib/python3.10/subprocess.py:1072: ResourceWarning: subprocess 8535 is still running
#   _warn("subprocess %s is still running" % self.pid,
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Utility Code

# %%
# !ps -fA | grep python
# Out:
# root          70       6  0 07:24 ?        00:00:17 [python3] <defunct>
# root          71       6  0 07:24 ?        00:00:01 python3 /usr/local/bin/colab-fileshim.py
# root          88       6  0 07:24 ?        00:00:10 /usr/bin/python3 /usr/local/bin/jupyter-notebook
# root         583     580  0 07:25 ?        00:00:00 python3 /opt/google/drive/drive-filter.py
# root        8328      88  1 07:55 ?        00:00:04 /usr/bin/python3 -m colab_kernel_launcher -f /ro
# root        8362       1  0 07:55 ?        00:00:01 /usr/bin/python3 /usr/local/lib/python3.10/dist-
# root        9430    8328  0 08:00 ?        00:00:00 /bin/bash -c ps -fA | grep python
# root        9432    9430  0 08:00 ?        00:00:00 grep python

# %%
# !kill 8328

# %%
# !taipy stop
# Out:
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# usage: taipy [-h] [-v] {run,manage-versions,create,migrate,help} ...
# taipy: error: argument {run,manage-versions,create,migrate,help}: invalid choice: 'stop' (choose from 'run', 'manage-versions', 'create', 'migrate', 'help')
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
# It seems that the gevent monkey-patching is being used.
# Please set an environment variable with:
# GEVENT_SUPPORT=True
# to enable gevent support in the debugger.
